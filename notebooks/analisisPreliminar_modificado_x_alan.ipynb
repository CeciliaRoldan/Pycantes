# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %run "../notebooks/cargar_df.ipynb"

plt.style.use('default')
sns.set(style="whitegrid")
pd.options.display.float_format = '{:20,.2f}'.format

# %%
data_folder  = "../data/"

# %%
train = pd.read_csv(data_folder + "Entrenamieto_ECI_2020.csv")

# %% [markdown]
# ### Analisis del set

# %%
#Obtengo la info basica del set de datos 
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 52 columns):
# ID                                    16947 non-null int64
# Region                                16947 non-null object
# Territory                             16947 non-null object
# Pricing, Delivery_Terms_Quote_Appr    16947 non-null int64
# Pricing, Delivery_Terms_Approved      16947 non-null int64
# Bureaucratic_Code_0_Approval          16947 non-null int64
# Bureaucratic_Code_0_Approved          16947 non-null int64
# Submitted_for_Approval                16947 non-null int64
# Bureaucratic_Code                     16947 non-null object
# Account_Created_Date                  16947 non-null object
# Source                                16947 non-null object
# Billing_Country                       16947 non-null object
# Account_Name                          16947 non-null object
# Opportunity_Name                      16947 non-null object
# Opportunity_ID                        16947 non-null int64
# Sales_Contract_No                     16947 non-null object
# Account_Owner                         16947 non-null object
# Opportunity_Owner                     16947 non-null object
# Account_Type                          16947 non-null object
# Opportunity_Type                      16947 non-null object
# Quote_Type                            16947 non-null object
# Delivery_Terms                        16947 non-null object
# Opportunity_Created_Date              16947 non-null object
# Brand                                 16947 non-null object
# Product_Type                          16947 non-null object
# Size                                  16947 non-null object
# Product_Category_B                    16947 non-null object
# Price                                 16947 non-null object
# Currency                              16947 non-null object
# Last_Activity                         16947 non-null object
# Quote_Expiry_Date                     16947 non-null object
# Last_Modified_Date                    16947 non-null object
# Last_Modified_By                      16947 non-null object
# Product_Family                        16947 non-null object
# Product_Name                          16947 non-null object
# ASP_Currency                          16947 non-null object
# ASP                                   13738 non-null float64
# ASP_(converted)_Currency              16947 non-null object
# ASP_(converted)                       13738 non-null float64
# Planned_Delivery_Start_Date           16947 non-null object
# Planned_Delivery_End_Date             16947 non-null object
# Month                                 16947 non-null object
# Delivery_Quarter                      16947 non-null object
# Delivery_Year                         16947 non-null int64
# Actual_Delivery_Date                  16947 non-null object
# TRF                                   16947 non-null int64
# Total_Amount_Currency                 16947 non-null object
# Total_Amount                          16888 non-null float64
# Total_Taxable_Amount_Currency         16947 non-null object
# Total_Taxable_Amount                  16947 non-null float64
# Stage                                 16947 non-null object
# Prod_Category_A                       16947 non-null object
# dtypes: float64(4), int64(9), object(39)
# memory usage: 6.7+ MB

# %%
#Visualizo las dimensiones del set
train.shape
# Out:
# (16947, 52)

# %%
#Vemos una porcion del mismo
train.head().T
# Out:
#                                                          0  \
# ID                                                   27761
# Region                                                EMEA
# Territory                                             None
# Pricing, Delivery_Terms_Quote_Appr                       1
# Pricing, Delivery_Terms_Approved                         1
# Bureaucratic_Code_0_Approval                             1
# Bureaucratic_Code_0_Approved                             1
# Submitted_for_Approval                                   0
# Bureaucratic_Code                      Bureaucratic_Code_4
# Account_Created_Date                             6/16/2015
# Source                                                None
# Billing_Country                                Netherlands
# Account_Name                              Account_Name_619
# Opportunity_Name                    Opportunity_Name_12598
# Opportunity_ID                                           0
# Sales_Contract_No                                     None
# Account_Owner                               Person_Name_51
# Opportunity_Owner                           Person_Name_18
# Account_Type                                Account_Type_2
# Opportunity_Type                        Opportunity_Type_1
# Quote_Type                                     Non Binding
# Delivery_Terms                            Delivery_Terms_2
# Opportunity_Created_Date                         12/7/2015
# Brand                                                 None
# Product_Type                                          None
# Size                                                  None
# Product_Category_B                                    None
# Price                                                 None
# Currency                                              None
# Last_Activity                                          NaT
# Quote_Expiry_Date                                1/30/2016
# Last_Modified_Date                               6/13/2016
# Last_Modified_By                            Person_Name_18
# Product_Family                           Product_Family_77
# Product_Name                               Product_Name_99
# ASP_Currency                                           EUR
# ASP                                                   0.52
# ASP_(converted)_Currency                               USD
# ASP_(converted)                                       0.59
# Planned_Delivery_Start_Date                       5/1/2016
# Planned_Delivery_End_Date                        6/30/2016
# Month                                             2016 - 5
# Delivery_Quarter                                        Q2
# Delivery_Year                                         2016
# Actual_Delivery_Date                                   NaT
# TRF                                                     10
# Total_Amount_Currency                                  EUR
# Total_Amount                                  5,272,800.00
# Total_Taxable_Amount_Currency                          EUR
# Total_Taxable_Amount                          5,272,800.00
# Stage                                          Closed Lost
# Prod_Category_A                       Prod_Category_A_None
#
#                                                          1  \
# ID                                                   27760
# Region                                                EMEA
# Territory                                             None
# Pricing, Delivery_Terms_Quote_Appr                       0
# Pricing, Delivery_Terms_Approved                         0
# Bureaucratic_Code_0_Approval                             0
# Bureaucratic_Code_0_Approved                             0
# Submitted_for_Approval                                   0
# Bureaucratic_Code                      Bureaucratic_Code_4
# Account_Created_Date                             6/16/2015
# Source                                                None
# Billing_Country                                Netherlands
# Account_Name                              Account_Name_619
# Opportunity_Name                    Opportunity_Name_12600
# Opportunity_ID                                           1
# Sales_Contract_No                                       39
# Account_Owner                               Person_Name_51
# Opportunity_Owner                           Person_Name_20
# Account_Type                                Account_Type_2
# Opportunity_Type                        Opportunity_Type_1
# Quote_Type                                     Non Binding
# Delivery_Terms                            Delivery_Terms_2
# Opportunity_Created_Date                         12/7/2015
# Brand                                                 None
# Product_Type                                          None
# Size                                                  None
# Product_Category_B                                    None
# Price                                                 None
# Currency                                              None
# Last_Activity                                          NaT
# Quote_Expiry_Date                                1/20/2016
# Last_Modified_Date                               1/15/2016
# Last_Modified_By                            Person_Name_20
# Product_Family                           Product_Family_77
# Product_Name                              Product_Name_100
# ASP_Currency                                           EUR
# ASP                                                   0.53
# ASP_(converted)_Currency                               USD
# ASP_(converted)                                       0.60
# Planned_Delivery_Start_Date                      1/18/2016
# Planned_Delivery_End_Date                        1/20/2016
# Month                                             2016 - 1
# Delivery_Quarter                                        Q1
# Delivery_Year                                         2016
# Actual_Delivery_Date                                   NaT
# TRF                                                      0
# Total_Amount_Currency                                  EUR
# Total_Amount                                     48,230.00
# Total_Taxable_Amount_Currency                          EUR
# Total_Taxable_Amount                             48,230.00
# Stage                                           Closed Won
# Prod_Category_A                       Prod_Category_A_None
#
#                                                        2  \
# ID                                                 27446
# Region                                          Americas
# Territory                                     NW America
# Pricing, Delivery_Terms_Quote_Appr                     0
# Pricing, Delivery_Terms_Approved                       0
# Bureaucratic_Code_0_Approval                           0
# Bureaucratic_Code_0_Approved                           0
# Submitted_for_Approval                                 0
# Bureaucratic_Code                    Bureaucratic_Code_4
# Account_Created_Date                           4/21/2015
# Source                                          Source_7
# Billing_Country                            United States
# Account_Name                           Account_Name_1794
# Opportunity_Name                    Opportunity_Name_469
# Opportunity_ID                                         2
# Sales_Contract_No                                    760
# Account_Owner                             Person_Name_64
# Opportunity_Owner                          Person_Name_8
# Account_Type                              Account_Type_5
# Opportunity_Type                      Opportunity_Type_1
# Quote_Type                                   Non Binding
# Delivery_Terms                          Delivery_Terms_4
# Opportunity_Created_Date                       12/8/2015
# Brand                                               None
# Product_Type                                        None
# Size                                                None
# Product_Category_B                                  None
# Price                                               None
# Currency                                            None
# Last_Activity                                        NaT
# Quote_Expiry_Date                              9/30/2016
# Last_Modified_Date                             9/29/2016
# Last_Modified_By                           Person_Name_8
# Product_Family                         Product_Family_81
# Product_Name                             Product_Name_91
# ASP_Currency                                         USD
# ASP                                                 0.48
# ASP_(converted)_Currency                             USD
# ASP_(converted)                                     0.48
# Planned_Delivery_Start_Date                    1/25/2016
# Planned_Delivery_End_Date                      1/25/2016
# Month                                           2016 - 1
# Delivery_Quarter                                      Q1
# Delivery_Year                                       2016
# Actual_Delivery_Date                                 NaT
# TRF                                                    0
# Total_Amount_Currency                                USD
# Total_Amount                                   83,865.60
# Total_Taxable_Amount_Currency                        USD
# Total_Taxable_Amount                           83,865.60
# Stage                                         Closed Won
# Prod_Category_A                     Prod_Category_A_None
#
#                                                         3  \
# ID                                                  16808
# Region                                           Americas
# Territory                                      NW America
# Pricing, Delivery_Terms_Quote_Appr                      1
# Pricing, Delivery_Terms_Approved                        0
# Bureaucratic_Code_0_Approval                            1
# Bureaucratic_Code_0_Approved                            0
# Submitted_for_Approval                                  0
# Bureaucratic_Code                     Bureaucratic_Code_5
# Account_Created_Date                            7/27/2013
# Source                                          Source_11
# Billing_Country                             United States
# Account_Name                            Account_Name_1201
# Opportunity_Name                     Opportunity_Name_415
# Opportunity_ID                                          3
# Sales_Contract_No                                    None
# Account_Owner                               Person_Name_8
# Opportunity_Owner                           Person_Name_8
# Account_Type                               Account_Type_5
# Opportunity_Type                      Opportunity_Type_19
# Quote_Type                                    Non Binding
# Delivery_Terms                           Delivery_Terms_1
# Opportunity_Created_Date                        12/8/2015
# Brand                                               Other
# Product_Type                               Product_Type_0
# Size                                               Size_4
# Product_Category_B                  Product_Category_B_16
# Price                                                0.42
# Currency                                              USD
# Last_Activity                                         NaT
# Quote_Expiry_Date                                     NaT
# Last_Modified_Date                              3/27/2018
# Last_Modified_By                            Person_Name_8
# Product_Family                         Product_Family_209
# Product_Name                             Product_Name_432
# ASP_Currency                                          USD
# ASP                                                  0.53
# ASP_(converted)_Currency                              USD
# ASP_(converted)                                      0.53
# Planned_Delivery_Start_Date                      2/1/2018
# Planned_Delivery_End_Date                       3/31/2018
# Month                                            2018 - 2
# Delivery_Quarter                                       Q1
# Delivery_Year                                        2018
# Actual_Delivery_Date                                  NaT
# TRF                                                    14
# Total_Amount_Currency                                 USD
# Total_Amount                                 7,421,881.50
# Total_Taxable_Amount_Currency                         USD
# Total_Taxable_Amount                         7,421,881.50
# Stage                                         Closed Lost
# Prod_Category_A                      Prod_Category_A_None
#
#                                                         4
# ID                                                  16805
# Region                                           Americas
# Territory                                      NW America
# Pricing, Delivery_Terms_Quote_Appr                      1
# Pricing, Delivery_Terms_Approved                        0
# Bureaucratic_Code_0_Approval                            1
# Bureaucratic_Code_0_Approved                            0
# Submitted_for_Approval                                  0
# Bureaucratic_Code                     Bureaucratic_Code_5
# Account_Created_Date                            7/27/2013
# Source                                          Source_11
# Billing_Country                             United States
# Account_Name                            Account_Name_1201
# Opportunity_Name                     Opportunity_Name_851
# Opportunity_ID                                          4
# Sales_Contract_No                                    None
# Account_Owner                               Person_Name_8
# Opportunity_Owner                           Person_Name_8
# Account_Type                               Account_Type_5
# Opportunity_Type                      Opportunity_Type_19
# Quote_Type                                    Non Binding
# Delivery_Terms                           Delivery_Terms_1
# Opportunity_Created_Date                        12/8/2015
# Brand                                               Other
# Product_Type                               Product_Type_0
# Size                                               Size_4
# Product_Category_B                  Product_Category_B_16
# Price                                                0.42
# Currency                                              USD
# Last_Activity                                         NaT
# Quote_Expiry_Date                                6/2/2017
# Last_Modified_Date                              3/27/2018
# Last_Modified_By                            Person_Name_8
# Product_Family                         Product_Family_209
# Product_Name                             Product_Name_432
# ASP_Currency                                          USD
# ASP                                                  0.53
# ASP_(converted)_Currency                              USD
# ASP_(converted)                                      0.53
# Planned_Delivery_Start_Date                      2/1/2018
# Planned_Delivery_End_Date                       2/28/2018
# Month                                            2018 - 2
# Delivery_Quarter                                       Q1
# Delivery_Year                                        2018
# Actual_Delivery_Date                                  NaT
# TRF                                                    25
# Total_Amount_Currency                                 USD
# Total_Amount                                13,357,192.50
# Total_Taxable_Amount_Currency                         USD
# Total_Taxable_Amount                        13,357,192.50
# Stage                                         Closed Lost
# Prod_Category_A                      Prod_Category_A_None

# %%
#Exploramos los tipos de datos
train.dtypes
# Out:
# ID                                      int64
# Region                                 object
# Territory                              object
# Pricing, Delivery_Terms_Quote_Appr      int64
# Pricing, Delivery_Terms_Approved        int64
# Bureaucratic_Code_0_Approval            int64
# Bureaucratic_Code_0_Approved            int64
# Submitted_for_Approval                  int64
# Bureaucratic_Code                      object
# Account_Created_Date                   object
# Source                                 object
# Billing_Country                        object
# Account_Name                           object
# Opportunity_Name                       object
# Opportunity_ID                          int64
# Sales_Contract_No                      object
# Account_Owner                          object
# Opportunity_Owner                      object
# Account_Type                           object
# Opportunity_Type                       object
# Quote_Type                             object
# Delivery_Terms                         object
# Opportunity_Created_Date               object
# Brand                                  object
# Product_Type                           object
# Size                                   object
# Product_Category_B                     object
# Price                                  object
# Currency                               object
# Last_Activity                          object
# Quote_Expiry_Date                      object
# Last_Modified_Date                     object
# Last_Modified_By                       object
# Product_Family                         object
# Product_Name                           object
# ASP_Currency                           object
# ASP                                   float64
# ASP_(converted)_Currency               object
# ASP_(converted)                       float64
# Planned_Delivery_Start_Date            object
# Planned_Delivery_End_Date              object
# Month                                  object
# Delivery_Quarter                       object
# Delivery_Year                           int64
# Actual_Delivery_Date                   object
# TRF                                     int64
# Total_Amount_Currency                  object
# Total_Amount                          float64
# Total_Taxable_Amount_Currency          object
# Total_Taxable_Amount                  float64
# Stage                                  object
# Prod_Category_A                        object
# dtype: object

# %%
#Vemos la cantidad de tipos de datos 
train.dtypes.value_counts()
# Out:
# object     39
# int64       9
# float64     4
# dtype: int64

# %%
#Vemos la cantidad de valores nulos en cada columna del set de datos
train.isnull().sum()
# Out:
# ID                                       0
# Region                                   0
# Territory                                0
# Pricing, Delivery_Terms_Quote_Appr       0
# Pricing, Delivery_Terms_Approved         0
# Bureaucratic_Code_0_Approval             0
# Bureaucratic_Code_0_Approved             0
# Submitted_for_Approval                   0
# Bureaucratic_Code                        0
# Account_Created_Date                     0
# Source                                   0
# Billing_Country                          0
# Account_Name                             0
# Opportunity_Name                         0
# Opportunity_ID                           0
# Sales_Contract_No                        0
# Account_Owner                            0
# Opportunity_Owner                        0
# Account_Type                             0
# Opportunity_Type                         0
# Quote_Type                               0
# Delivery_Terms                           0
# Opportunity_Created_Date                 0
# Brand                                    0
# Product_Type                             0
# Size                                     0
# Product_Category_B                       0
# Price                                    0
# Currency                                 0
# Last_Activity                            0
# Quote_Expiry_Date                        0
# Last_Modified_Date                       0
# Last_Modified_By                         0
# Product_Family                           0
# Product_Name                             0
# ASP_Currency                             0
# ASP                                   3209
# ASP_(converted)_Currency                 0
# ASP_(converted)                       3209
# Planned_Delivery_Start_Date              0
# Planned_Delivery_End_Date                0
# Month                                    0
# Delivery_Quarter                         0
# Delivery_Year                            0
# Actual_Delivery_Date                     0
# TRF                                      0
# Total_Amount_Currency                    0
# Total_Amount                            59
# Total_Taxable_Amount_Currency            0
# Total_Taxable_Amount                     0
# Stage                                    0
# Prod_Category_A                          0
# dtype: int64

# %%
#Inspeccionamos las columnas del data frame con mas detalle,en particular datos de tipo numerio ,categorico y object
train.describe(include=[np.int64,np.float64,np.object, pd.Categorical]).T
# Out:
#                                                   count unique  \
# ID                                            16,947.00    NaN
# Region                                            16947      5
# Territory                                         16947     76
# Pricing, Delivery_Terms_Quote_Appr            16,947.00    NaN
# Pricing, Delivery_Terms_Approved              16,947.00    NaN
# Bureaucratic_Code_0_Approval                  16,947.00    NaN
# Bureaucratic_Code_0_Approved                  16,947.00    NaN
# Submitted_for_Approval                        16,947.00    NaN
# Bureaucratic_Code                                 16947      7
# Account_Created_Date                              16947    809
# Source                                            16947     14
# Billing_Country                                   16947     80
# Account_Name                                      16947   1635
# Opportunity_Name                                  16947   9841
# Opportunity_ID                                16,947.00    NaN
# Sales_Contract_No                                 16947   5267
# Account_Owner                                     16947     48
# Opportunity_Owner                                 16947     53
# Account_Type                                      16947      7
# Opportunity_Type                                  16947     25
# Quote_Type                                        16947      2
# Delivery_Terms                                    16947      9
# Opportunity_Created_Date                          16947   1096
# Brand                                             16947     26
# Product_Type                                      16947      7
# Size                                              16947      7
# Product_Category_B                                16947     28
# Price                                             16947     53
# Currency                                          16947      3
# Last_Activity                                     16947      1
# Quote_Expiry_Date                                 16947   1003
# Last_Modified_Date                                16947    650
# Last_Modified_By                                  16947     55
# Product_Family                                    16947    227
# Product_Name                                      16947    456
# ASP_Currency                                      16947      5
# ASP                                           13,738.00    NaN
# ASP_(converted)_Currency                          16947      1
# ASP_(converted)                               13,738.00    NaN
# Planned_Delivery_Start_Date                       16947    986
# Planned_Delivery_End_Date                         16947   1017
# Month                                             16947     53
# Delivery_Quarter                                  16947      4
# Delivery_Year                                 16,947.00    NaN
# Actual_Delivery_Date                              16947      1
# TRF                                           16,947.00    NaN
# Total_Amount_Currency                             16947      5
# Total_Amount                                  16,888.00    NaN
# Total_Taxable_Amount_Currency                     16947      5
# Total_Taxable_Amount                          16,947.00    NaN
# Stage                                             16947      5
# Prod_Category_A                                   16947      1
#
#                                                       top   freq  \
# ID                                                    NaN    NaN
# Region                                              Japan   4892
# Territory                                            None   4999
# Pricing, Delivery_Terms_Quote_Appr                    NaN    NaN
# Pricing, Delivery_Terms_Approved                      NaN    NaN
# Bureaucratic_Code_0_Approval                          NaN    NaN
# Bureaucratic_Code_0_Approved                          NaN    NaN
# Submitted_for_Approval                                NaN    NaN
# Bureaucratic_Code                     Bureaucratic_Code_4  12587
# Account_Created_Date                            4/20/2015   3011
# Source                                               None   9497
# Billing_Country                                     Japan   4879
# Account_Name                            Account_Name_1888   2124
# Opportunity_Name                    Opportunity_Name_5036     36
# Opportunity_ID                                        NaN    NaN
# Sales_Contract_No                                    None   6973
# Account_Owner                              Person_Name_50   3730
# Opportunity_Owner                          Person_Name_50   3781
# Account_Type                               Account_Type_2   8832
# Opportunity_Type                       Opportunity_Type_1   6819
# Quote_Type                                    Non Binding  16777
# Delivery_Terms                           Delivery_Terms_4   7712
# Opportunity_Created_Date                        6/30/2017    124
# Brand                                                None  15911
# Product_Type                                         None  15935
# Size                                                 None  15967
# Product_Category_B                                   None  15928
# Price                                                None  15982
# Currency                                             None  16052
# Last_Activity                                         NaT  16947
# Quote_Expiry_Date                                     NaT   4625
# Last_Modified_Date                               2/8/2018   5821
# Last_Modified_By                           Person_Name_47   8515
# Product_Family                          Product_Family_77   1345
# Product_Name                             Product_Name_100    976
# ASP_Currency                                          USD   7361
# ASP                                                   NaN    NaN
# ASP_(converted)_Currency                              USD  16947
# ASP_(converted)                                       NaN    NaN
# Planned_Delivery_Start_Date                     3/31/2016    381
# Planned_Delivery_End_Date                       3/31/2016    451
# Month                                           2018 - 10    666
# Delivery_Quarter                                       Q2   4443
# Delivery_Year                                         NaN    NaN
# Actual_Delivery_Date                                  NaT  16947
# TRF                                                   NaN    NaN
# Total_Amount_Currency                                 USD   7361
# Total_Amount                                          NaN    NaN
# Total_Taxable_Amount_Currency                         USD   7347
# Total_Taxable_Amount                                  NaN    NaN
# Stage                                          Closed Won   9533
# Prod_Category_A                      Prod_Category_A_None  16947
#
#                                                    mean                  std  \
# ID                                            17,666.65             6,940.86
# Region                                              NaN                  NaN
# Territory                                           NaN                  NaN
# Pricing, Delivery_Terms_Quote_Appr                 0.81                 0.39
# Pricing, Delivery_Terms_Approved                   0.58                 0.49
# Bureaucratic_Code_0_Approval                       0.48                 0.50
# Bureaucratic_Code_0_Approved                       0.32                 0.47
# Submitted_for_Approval                             0.00                 0.00
# Bureaucratic_Code                                   NaN                  NaN
# Account_Created_Date                                NaN                  NaN
# Source                                              NaN                  NaN
# Billing_Country                                     NaN                  NaN
# Account_Name                                        NaN                  NaN
# Opportunity_Name                                    NaN                  NaN
# Opportunity_ID                                 5,335.94             3,324.72
# Sales_Contract_No                                   NaN                  NaN
# Account_Owner                                       NaN                  NaN
# Opportunity_Owner                                   NaN                  NaN
# Account_Type                                        NaN                  NaN
# Opportunity_Type                                    NaN                  NaN
# Quote_Type                                          NaN                  NaN
# Delivery_Terms                                      NaN                  NaN
# Opportunity_Created_Date                            NaN                  NaN
# Brand                                               NaN                  NaN
# Product_Type                                        NaN                  NaN
# Size                                                NaN                  NaN
# Product_Category_B                                  NaN                  NaN
# Price                                               NaN                  NaN
# Currency                                            NaN                  NaN
# Last_Activity                                       NaN                  NaN
# Quote_Expiry_Date                                   NaN                  NaN
# Last_Modified_Date                                  NaN                  NaN
# Last_Modified_By                                    NaN                  NaN
# Product_Family                                      NaN                  NaN
# Product_Name                                        NaN                  NaN
# ASP_Currency                                        NaN                  NaN
# ASP                                                7.01                18.86
# ASP_(converted)_Currency                            NaN                  NaN
# ASP_(converted)                                    0.43                 0.76
# Planned_Delivery_Start_Date                         NaN                  NaN
# Planned_Delivery_End_Date                           NaN                  NaN
# Month                                               NaN                  NaN
# Delivery_Quarter                                    NaN                  NaN
# Delivery_Year                                  2,017.14                 0.83
# Actual_Delivery_Date                                NaN                  NaN
# TRF                                                2.34                12.17
# Total_Amount_Currency                               NaN                  NaN
# Total_Amount                               1,993,659.22        18,484,259.88
# Total_Taxable_Amount_Currency                       NaN                  NaN
# Total_Taxable_Amount                       3,224,116.79        20,303,604.73
# Stage                                               NaN                  NaN
# Prod_Category_A                                     NaN                  NaN
#
#                                                     min                  25%  \
# ID                                             4,854.00            11,953.00
# Region                                              NaN                  NaN
# Territory                                           NaN                  NaN
# Pricing, Delivery_Terms_Quote_Appr                 0.00                 1.00
# Pricing, Delivery_Terms_Approved                   0.00                 0.00
# Bureaucratic_Code_0_Approval                       0.00                 0.00
# Bureaucratic_Code_0_Approved                       0.00                 0.00
# Submitted_for_Approval                             0.00                 0.00
# Bureaucratic_Code                                   NaN                  NaN
# Account_Created_Date                                NaN                  NaN
# Source                                              NaN                  NaN
# Billing_Country                                     NaN                  NaN
# Account_Name                                        NaN                  NaN
# Opportunity_Name                                    NaN                  NaN
# Opportunity_ID                                     0.00             2,448.50
# Sales_Contract_No                                   NaN                  NaN
# Account_Owner                                       NaN                  NaN
# Opportunity_Owner                                   NaN                  NaN
# Account_Type                                        NaN                  NaN
# Opportunity_Type                                    NaN                  NaN
# Quote_Type                                          NaN                  NaN
# Delivery_Terms                                      NaN                  NaN
# Opportunity_Created_Date                            NaN                  NaN
# Brand                                               NaN                  NaN
# Product_Type                                        NaN                  NaN
# Size                                                NaN                  NaN
# Product_Category_B                                  NaN                  NaN
# Price                                               NaN                  NaN
# Currency                                            NaN                  NaN
# Last_Activity                                       NaN                  NaN
# Quote_Expiry_Date                                   NaN                  NaN
# Last_Modified_Date                                  NaN                  NaN
# Last_Modified_By                                    NaN                  NaN
# Product_Family                                      NaN                  NaN
# Product_Name                                        NaN                  NaN
# ASP_Currency                                        NaN                  NaN
# ASP                                                0.00                 0.36
# ASP_(converted)_Currency                            NaN                  NaN
# ASP_(converted)                                    0.00                 0.37
# Planned_Delivery_Start_Date                         NaN                  NaN
# Planned_Delivery_End_Date                           NaN                  NaN
# Month                                               NaN                  NaN
# Delivery_Quarter                                    NaN                  NaN
# Delivery_Year                                  2,016.00             2,016.00
# Actual_Delivery_Date                                NaN                  NaN
# TRF                                                0.00                 0.00
# Total_Amount_Currency                               NaN                  NaN
# Total_Amount                                       0.00            26,775.00
# Total_Taxable_Amount_Currency                       NaN                  NaN
# Total_Taxable_Amount                               0.00            85,465.80
# Stage                                               NaN                  NaN
# Prod_Category_A                                     NaN                  NaN
#
#                                                     50%                  75%  \
# ID                                            18,114.00            23,845.50
# Region                                              NaN                  NaN
# Territory                                           NaN                  NaN
# Pricing, Delivery_Terms_Quote_Appr                 1.00                 1.00
# Pricing, Delivery_Terms_Approved                   1.00                 1.00
# Bureaucratic_Code_0_Approval                       0.00                 1.00
# Bureaucratic_Code_0_Approved                       0.00                 1.00
# Submitted_for_Approval                             0.00                 0.00
# Bureaucratic_Code                                   NaN                  NaN
# Account_Created_Date                                NaN                  NaN
# Source                                              NaN                  NaN
# Billing_Country                                     NaN                  NaN
# Account_Name                                        NaN                  NaN
# Opportunity_Name                                    NaN                  NaN
# Opportunity_ID                                 5,306.00             7,698.00
# Sales_Contract_No                                   NaN                  NaN
# Account_Owner                                       NaN                  NaN
# Opportunity_Owner                                   NaN                  NaN
# Account_Type                                        NaN                  NaN
# Opportunity_Type                                    NaN                  NaN
# Quote_Type                                          NaN                  NaN
# Delivery_Terms                                      NaN                  NaN
# Opportunity_Created_Date                            NaN                  NaN
# Brand                                               NaN                  NaN
# Product_Type                                        NaN                  NaN
# Size                                                NaN                  NaN
# Product_Category_B                                  NaN                  NaN
# Price                                               NaN                  NaN
# Currency                                            NaN                  NaN
# Last_Activity                                       NaN                  NaN
# Quote_Expiry_Date                                   NaN                  NaN
# Last_Modified_Date                                  NaN                  NaN
# Last_Modified_By                                    NaN                  NaN
# Product_Family                                      NaN                  NaN
# Product_Name                                        NaN                  NaN
# ASP_Currency                                        NaN                  NaN
# ASP                                                0.40                 0.51
# ASP_(converted)_Currency                            NaN                  NaN
# ASP_(converted)                                    0.41                 0.48
# Planned_Delivery_Start_Date                         NaN                  NaN
# Planned_Delivery_End_Date                           NaN                  NaN
# Month                                               NaN                  NaN
# Delivery_Quarter                                    NaN                  NaN
# Delivery_Year                                  2,017.00             2,018.00
# Actual_Delivery_Date                                NaN                  NaN
# TRF                                                0.00                 1.00
# Total_Amount_Currency                               NaN                  NaN
# Total_Amount                                 107,250.00           460,389.83
# Total_Taxable_Amount_Currency                       NaN                  NaN
# Total_Taxable_Amount                         376,067.25         1,037,450.00
# Stage                                               NaN                  NaN
# Prod_Category_A                                     NaN                  NaN
#
#                                                     max
# ID                                            28,773.00
# Region                                              NaN
# Territory                                           NaN
# Pricing, Delivery_Terms_Quote_Appr                 1.00
# Pricing, Delivery_Terms_Approved                   1.00
# Bureaucratic_Code_0_Approval                       1.00
# Bureaucratic_Code_0_Approved                       1.00
# Submitted_for_Approval                             0.00
# Bureaucratic_Code                                   NaN
# Account_Created_Date                                NaN
# Source                                              NaN
# Billing_Country                                     NaN
# Account_Name                                        NaN
# Opportunity_Name                                    NaN
# Opportunity_ID                                12,803.00
# Sales_Contract_No                                   NaN
# Account_Owner                                       NaN
# Opportunity_Owner                                   NaN
# Account_Type                                        NaN
# Opportunity_Type                                    NaN
# Quote_Type                                          NaN
# Delivery_Terms                                      NaN
# Opportunity_Created_Date                            NaN
# Brand                                               NaN
# Product_Type                                        NaN
# Size                                                NaN
# Product_Category_B                                  NaN
# Price                                               NaN
# Currency                                            NaN
# Last_Activity                                       NaN
# Quote_Expiry_Date                                   NaN
# Last_Modified_Date                                  NaN
# Last_Modified_By                                    NaN
# Product_Family                                      NaN
# Product_Name                                        NaN
# ASP_Currency                                        NaN
# ASP                                               80.00
# ASP_(converted)_Currency                            NaN
# ASP_(converted)                                   67.00
# Planned_Delivery_Start_Date                         NaN
# Planned_Delivery_End_Date                           NaN
# Month                                               NaN
# Delivery_Quarter                                    NaN
# Delivery_Year                                  2,020.00
# Actual_Delivery_Date                                NaN
# TRF                                              500.00
# Total_Amount_Currency                               NaN
# Total_Amount                           1,320,000,000.00
# Total_Taxable_Amount_Currency                       NaN
# Total_Taxable_Amount                   1,356,338,620.00
# Stage                                               NaN
# Prod_Category_A                                     NaN

# %%
#Viendo que hay columnas de tipo int64 ,analizamos si estas pueden optimizarse cambiando el formato
train["ID"].max()
# Out:
# 28773

# %%
train["Pricing, Delivery_Terms_Quote_Appr"].max()
# Out:
# 1

# %%
train["Pricing, Delivery_Terms_Approved"].max()
# Out:
# 1

# %%
train["Submitted_for_Approval"].max()
# Out:
# 0

# %%
#Observamos que varias columnas pueden optimizarse cambiando sus tipos de datos para lograr un menor uso de la memoria
#al momento de cargar el set de datos.
#Creamos ademas una funcion de carga del dataframe para usar en general en cada analisis exploratorio
#(ver en cargar_df.ipynb)
train2=get_train()

# %%
#Visualizamos ahora con la funcion de carga, los tipos de datos modificados y su consumo de memoria
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 47 columns):
# ID                                    16947 non-null int16
# Region                                16947 non-null category
# Territory                             16947 non-null category
# Pricing, Delivery_Terms_Quote_Appr    16947 non-null int16
# Pricing, Delivery_Terms_Approved      16947 non-null int16
# Bureaucratic_Code_0_Approval          16947 non-null category
# Bureaucratic_Code_0_Approved          16947 non-null category
# Bureaucratic_Code                     16947 non-null category
# Account_Created_Date                  16947 non-null datetime64[ns]
# Source                                16947 non-null object
# Billing_Country                       16947 non-null category
# Account_Name                          16947 non-null object
# Opportunity_Name                      16947 non-null object
# Opportunity_ID                        16947 non-null int64
# Sales_Contract_No                     16947 non-null object
# Account_Owner                         16947 non-null category
# Opportunity_Owner                     16947 non-null category
# Account_Type                          16947 non-null category
# Opportunity_Type                      16947 non-null category
# Quote_Type                            16947 non-null category
# Delivery_Terms                        16947 non-null category
# Opportunity_Created_Date              16947 non-null datetime64[ns]
# Brand                                 16947 non-null category
# Product_Type                          16947 non-null category
# Size                                  16947 non-null category
# Product_Category_B                    16947 non-null category
# Price                                 16947 non-null category
# Currency                              16947 non-null category
# Quote_Expiry_Date                     16947 non-null object
# Last_Modified_Date                    16947 non-null datetime64[ns]
# Last_Modified_By                      16947 non-null object
# Product_Family                        16947 non-null category
# Product_Name                          16947 non-null object
# ASP_Currency                          16947 non-null category
# ASP                                   13738 non-null float64
# ASP_(converted)                       13738 non-null float64
# Planned_Delivery_Start_Date           16947 non-null datetime64[ns]
# Planned_Delivery_End_Date             16872 non-null datetime64[ns]
# Month                                 16947 non-null datetime64[ns]
# Delivery_Quarter                      16947 non-null category
# Delivery_Year                         16947 non-null int16
# TRF                                   16947 non-null int64
# Total_Amount_Currency                 16947 non-null category
# Total_Amount                          16888 non-null float64
# Total_Taxable_Amount_Currency         16947 non-null category
# Total_Taxable_Amount                  16947 non-null float64
# Stage                                 16947 non-null object
# dtypes: category(23), datetime64[ns](6), float64(4), int16(4), int64(2), object(8)
# memory usage: 3.1+ MB

# %%
train["Stage"].value_counts()
# Out:
# Closed Won       9533
# Closed Lost      7350
# Proposal           35
# Negotiation        18
# Qualification      11
# Name: Stage, dtype: int64

# %%
train["Territory"].value_counts()
# Out:
# None                    4999
# Germany                 1682
# NW America              1568
# Australia               1208
# India                    809
# NE America               760
# Japan                    681
# Netherlands              533
# SE America               493
# France                   449
# Singapore                441
# United Kingdom           313
# Belgium                  285
# Italy                    283
# Spain                    268
# Central US               254
# China (PRC)              218
# SW America               206
# Thailand                 173
# Indonesia                154
# Austria                  145
# Philippines              109
# Jordan                   102
# Canada                    74
# Luxembourg                70
# Portugal                  66
# Poland                    60
# Vietnam                   51
# Cyprus                    44
# Denmark                   38
#                         ...
# Kazakhstan                 7
# Pakistan                   6
# Malta                      6
# Macedonia                  6
# Saudi Arabia               6
# Ukraine                    5
# Bulgaria                   5
# Tunisia                    5
# Malaysia                   5
# Bosnia & Herzegovina       4
# Belarus                    4
# Oman                       4
# Kuwait                     4
# Cambodia                   4
# Morocco                    3
# South East Asia            2
# UAE (Others)               2
# Romania                    2
# Armenia                    2
# Kosovo                     2
# Albania                    2
# Lebanon                    2
# Solomon Islands            1
# Croatia                    1
# Egypt                      1
# Slovenia                   1
# Monaco                     1
# Czech Republic             1
# Burma                      1
# Georgia                    1
# Name: Territory, Length: 76, dtype: int64

# %%
train["Region"].value_counts()
# Out:
# Japan          4892
# EMEA           4664
# Americas       3945
# APAC           3262
# Middle East     184
# Name: Region, dtype: int64

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 47 columns):
# ID                                    16947 non-null int16
# Region                                16947 non-null category
# Territory                             16947 non-null category
# Pricing, Delivery_Terms_Quote_Appr    16947 non-null int16
# Pricing, Delivery_Terms_Approved      16947 non-null int16
# Bureaucratic_Code_0_Approval          16947 non-null category
# Bureaucratic_Code_0_Approved          16947 non-null category
# Bureaucratic_Code                     16947 non-null category
# Account_Created_Date                  16947 non-null datetime64[ns]
# Source                                16947 non-null object
# Billing_Country                       16947 non-null category
# Account_Name                          16947 non-null object
# Opportunity_Name                      16947 non-null object
# Opportunity_ID                        16947 non-null int64
# Sales_Contract_No                     16947 non-null object
# Account_Owner                         16947 non-null category
# Opportunity_Owner                     16947 non-null category
# Account_Type                          16947 non-null category
# Opportunity_Type                      16947 non-null category
# Quote_Type                            16947 non-null category
# Delivery_Terms                        16947 non-null category
# Opportunity_Created_Date              16947 non-null datetime64[ns]
# Brand                                 16947 non-null category
# Product_Type                          16947 non-null category
# Size                                  16947 non-null category
# Product_Category_B                    16947 non-null category
# Price                                 16947 non-null category
# Currency                              16947 non-null category
# Quote_Expiry_Date                     16947 non-null object
# Last_Modified_Date                    16947 non-null datetime64[ns]
# Last_Modified_By                      16947 non-null object
# Product_Family                        16947 non-null category
# Product_Name                          16947 non-null object
# ASP_Currency                          16947 non-null category
# ASP                                   13738 non-null float64
# ASP_(converted)                       13738 non-null float64
# Planned_Delivery_Start_Date           16947 non-null datetime64[ns]
# Planned_Delivery_End_Date             16872 non-null datetime64[ns]
# Month                                 16947 non-null datetime64[ns]
# Delivery_Quarter                      16947 non-null category
# Delivery_Year                         16947 non-null int16
# TRF                                   16947 non-null int64
# Total_Amount_Currency                 16947 non-null category
# Total_Amount                          16888 non-null float64
# Total_Taxable_Amount_Currency         16947 non-null category
# Total_Taxable_Amount                  16947 non-null float64
# Stage                                 16947 non-null object
# dtypes: category(23), datetime64[ns](6), float64(4), int16(4), int64(2), object(8)
# memory usage: 3.1+ MB

# %%
# Muestro la cantidad de valores distintos que tiene cada columna
print('Valores distintos - Columna')
for column in train.columns:
    print(train[column].value_counts().count(), '\t', column)
# Out:
# Valores distintos - Columna
# 16947 	 ID
# 5 	 Region
# 76 	 Territory
# 2 	 Pricing, Delivery_Terms_Quote_Appr
# 2 	 Pricing, Delivery_Terms_Approved
# 2 	 Bureaucratic_Code_0_Approval
# 2 	 Bureaucratic_Code_0_Approved
# 1 	 Submitted_for_Approval
# 7 	 Bureaucratic_Code
# 809 	 Account_Created_Date
# 14 	 Source
# 80 	 Billing_Country
# 1635 	 Account_Name
# 9841 	 Opportunity_Name
# 9841 	 Opportunity_ID
# 5267 	 Sales_Contract_No
# 48 	 Account_Owner
# 53 	 Opportunity_Owner
# 7 	 Account_Type
# 25 	 Opportunity_Type
# 2 	 Quote_Type
# 9 	 Delivery_Terms
# 1096 	 Opportunity_Created_Date
# 26 	 Brand
# 7 	 Product_Type
# 7 	 Size
# 28 	 Product_Category_B
# 53 	 Price
# 3 	 Currency
# 1 	 Last_Activity
# 1003 	 Quote_Expiry_Date
# 650 	 Last_Modified_Date
# 55 	 Last_Modified_By
# 227 	 Product_Family
# 456 	 Product_Name
# 5 	 ASP_Currency
# 301 	 ASP
# 1 	 ASP_(converted)_Currency
# 441 	 ASP_(converted)
# 986 	 Planned_Delivery_Start_Date
# 1017 	 Planned_Delivery_End_Date
# 53 	 Month
# 4 	 Delivery_Quarter
# 5 	 Delivery_Year
# 1 	 Actual_Delivery_Date
# 101 	 TRF
# 5 	 Total_Amount_Currency
# 8872 	 Total_Amount
# 5 	 Total_Taxable_Amount_Currency
# 7096 	 Total_Taxable_Amount
# 5 	 Stage
# 1 	 Prod_Category_A

# %% [markdown]
# Hay columnas del data frame que tienen el mismo valor en todos los registros y no aportan información

# %%
#train2.drop(['Prod_Category_A', 'Actual_Delivery_Date', 'ASP_(converted)_Currency', 'Last_Activity', 'Submitted_for_Approval'], 
#            axis=1, inplace=True)

# Muestro la cantidad de valores distintos que tiene cada columna
print('Valores distintos - Columna')
for column in train2.columns:
    print(train2[column].value_counts().count(), '\t', column)
# Out:
# Valores distintos - Columna
# 16947 	 ID
# 5 	 Region
# 76 	 Territory
# 2 	 Pricing, Delivery_Terms_Quote_Appr
# 2 	 Pricing, Delivery_Terms_Approved
# 2 	 Bureaucratic_Code_0_Approval
# 2 	 Bureaucratic_Code_0_Approved
# 7 	 Bureaucratic_Code
# 809 	 Account_Created_Date
# 14 	 Source
# 80 	 Billing_Country
# 1635 	 Account_Name
# 9841 	 Opportunity_Name
# 9841 	 Opportunity_ID
# 5267 	 Sales_Contract_No
# 48 	 Account_Owner
# 53 	 Opportunity_Owner
# 7 	 Account_Type
# 25 	 Opportunity_Type
# 2 	 Quote_Type
# 9 	 Delivery_Terms
# 1096 	 Opportunity_Created_Date
# 26 	 Brand
# 7 	 Product_Type
# 7 	 Size
# 28 	 Product_Category_B
# 53 	 Price
# 3 	 Currency
# 1003 	 Quote_Expiry_Date
# 650 	 Last_Modified_Date
# 55 	 Last_Modified_By
# 227 	 Product_Family
# 456 	 Product_Name
# 5 	 ASP_Currency
# 301 	 ASP
# 441 	 ASP_(converted)
# 986 	 Planned_Delivery_Start_Date
# 1016 	 Planned_Delivery_End_Date
# 53 	 Month
# 4 	 Delivery_Quarter
# 5 	 Delivery_Year
# 101 	 TRF
# 5 	 Total_Amount_Currency
# 8872 	 Total_Amount
# 5 	 Total_Taxable_Amount_Currency
# 7096 	 Total_Taxable_Amount
# 5 	 Stage

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 47 columns):
# ID                                    16947 non-null int16
# Region                                16947 non-null category
# Territory                             16947 non-null category
# Pricing, Delivery_Terms_Quote_Appr    16947 non-null int16
# Pricing, Delivery_Terms_Approved      16947 non-null int16
# Bureaucratic_Code_0_Approval          16947 non-null category
# Bureaucratic_Code_0_Approved          16947 non-null category
# Bureaucratic_Code                     16947 non-null category
# Account_Created_Date                  16947 non-null datetime64[ns]
# Source                                16947 non-null object
# Billing_Country                       16947 non-null category
# Account_Name                          16947 non-null object
# Opportunity_Name                      16947 non-null object
# Opportunity_ID                        16947 non-null int64
# Sales_Contract_No                     16947 non-null object
# Account_Owner                         16947 non-null category
# Opportunity_Owner                     16947 non-null category
# Account_Type                          16947 non-null category
# Opportunity_Type                      16947 non-null category
# Quote_Type                            16947 non-null category
# Delivery_Terms                        16947 non-null category
# Opportunity_Created_Date              16947 non-null datetime64[ns]
# Brand                                 16947 non-null category
# Product_Type                          16947 non-null category
# Size                                  16947 non-null category
# Product_Category_B                    16947 non-null category
# Price                                 16947 non-null category
# Currency                              16947 non-null category
# Quote_Expiry_Date                     16947 non-null object
# Last_Modified_Date                    16947 non-null datetime64[ns]
# Last_Modified_By                      16947 non-null object
# Product_Family                        16947 non-null category
# Product_Name                          16947 non-null object
# ASP_Currency                          16947 non-null category
# ASP                                   13738 non-null float64
# ASP_(converted)                       13738 non-null float64
# Planned_Delivery_Start_Date           16947 non-null datetime64[ns]
# Planned_Delivery_End_Date             16872 non-null datetime64[ns]
# Month                                 16947 non-null datetime64[ns]
# Delivery_Quarter                      16947 non-null category
# Delivery_Year                         16947 non-null int16
# TRF                                   16947 non-null int64
# Total_Amount_Currency                 16947 non-null category
# Total_Amount                          16888 non-null float64
# Total_Taxable_Amount_Currency         16947 non-null category
# Total_Taxable_Amount                  16947 non-null float64
# Stage                                 16947 non-null object
# dtypes: category(23), datetime64[ns](6), float64(4), int16(4), int64(2), object(8)
# memory usage: 3.1+ MB

# %%
# Muestro la cantidad de valores 'None' que tiene cada columna
print('Valores distintos - Columna')
for column in train2.columns:
    print(train2[train2[column] == 'None'][column].count(), '/', train2[column].count(), '\t', column)
# Out:
# Valores distintos - Columna
# 0 / 16947 	 ID
# 0 / 16947 	 Region
# 4999 / 16947 	 Territory
# 0 / 16947 	 Pricing, Delivery_Terms_Quote_Appr
# 0 / 16947 	 Pricing, Delivery_Terms_Approved
# 0 / 16947 	 Bureaucratic_Code_0_Approval
# 0 / 16947 	 Bureaucratic_Code_0_Approved
# 0 / 16947 	 Bureaucratic_Code
# 0 / 16947 	 Account_Created_Date
# 9497 / 16947 	 Source
# 27 / 16947 	 Billing_Country
# 0 / 16947 	 Account_Name
# 0 / 16947 	 Opportunity_Name
# 0 / 16947 	 Opportunity_ID
# 6973 / 16947 	 Sales_Contract_No
# 0 / 16947 	 Account_Owner
# 0 / 16947 	 Opportunity_Owner
# 112 / 16947 	 Account_Type
# 0 / 16947 	 Opportunity_Type
# 0 / 16947 	 Quote_Type
# 0 / 16947 	 Delivery_Terms
# 0 / 16947 	 Opportunity_Created_Date
# 15911 / 16947 	 Brand
# 15935 / 16947 	 Product_Type
# 15967 / 16947 	 Size
# 15928 / 16947 	 Product_Category_B
# 15982 / 16947 	 Price
# 16052 / 16947 	 Currency
# 0 / 16947 	 Quote_Expiry_Date
# 0 / 16947 	 Last_Modified_Date
# 0 / 16947 	 Last_Modified_By
# 0 / 16947 	 Product_Family
# 0 / 16947 	 Product_Name
# 0 / 16947 	 ASP_Currency
# 0 / 13738 	 ASP
# 0 / 13738 	 ASP_(converted)
# 0 / 16947 	 Planned_Delivery_Start_Date
# 0 / 16872 	 Planned_Delivery_End_Date
# 0 / 16947 	 Month
# 0 / 16947 	 Delivery_Quarter
# 0 / 16947 	 Delivery_Year
# 0 / 16947 	 TRF
# 0 / 16947 	 Total_Amount_Currency
# 0 / 16888 	 Total_Amount
# 0 / 16947 	 Total_Taxable_Amount_Currency
# 0 / 16947 	 Total_Taxable_Amount
# 0 / 16947 	 Stage

# %% [markdown]
# Se descartan Source, Brand, Product_Type, Size, Product_Category_B, Price, Currency por falta de datos (>50%)

# %%
train2.drop(['Source', 'Brand', 'Product_Type', 'Size', 'Product_Category_B', 'Price', 'Currency'], 
            axis=1, inplace=True)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 41 columns):
# ID                                    16947 non-null int16
# Region                                16947 non-null category
# Territory                             16947 non-null category
# Pricing, Delivery_Terms_Quote_Appr    16947 non-null int16
# Pricing, Delivery_Terms_Approved      16947 non-null int16
# Bureaucratic_Code_0_Approval          16947 non-null category
# Bureaucratic_Code_0_Approved          16947 non-null category
# Bureaucratic_Code                     16947 non-null category
# Account_Created_Date                  16947 non-null datetime64[ns]
# Source                                16947 non-null object
# Billing_Country                       16947 non-null category
# Account_Name                          16947 non-null object
# Opportunity_Name                      16947 non-null object
# Opportunity_ID                        16947 non-null int64
# Sales_Contract_No                     16947 non-null object
# Account_Owner                         16947 non-null category
# Opportunity_Owner                     16947 non-null category
# Account_Type                          16947 non-null category
# Opportunity_Type                      16947 non-null category
# Quote_Type                            16947 non-null category
# Delivery_Terms                        16947 non-null category
# Opportunity_Created_Date              16947 non-null datetime64[ns]
# Quote_Expiry_Date                     16947 non-null object
# Last_Modified_Date                    16947 non-null datetime64[ns]
# Last_Modified_By                      16947 non-null object
# Product_Family                        16947 non-null category
# Product_Name                          16947 non-null object
# ASP_Currency                          16947 non-null category
# ASP                                   13738 non-null float64
# ASP_(converted)                       13738 non-null float64
# Planned_Delivery_Start_Date           16947 non-null datetime64[ns]
# Planned_Delivery_End_Date             16872 non-null datetime64[ns]
# Month                                 16947 non-null datetime64[ns]
# Delivery_Quarter                      16947 non-null category
# Delivery_Year                         16947 non-null int16
# TRF                                   16947 non-null int64
# Total_Amount_Currency                 16947 non-null category
# Total_Amount                          16888 non-null float64
# Total_Taxable_Amount_Currency         16947 non-null category
# Total_Taxable_Amount                  16947 non-null float64
# Stage                                 16947 non-null object
# dtypes: category(17), datetime64[ns](6), float64(4), int16(4), int64(2), object(8)
# memory usage: 3.0+ MB

# %%
# Muestro la cantidad de valores nan que tiene cada columna
print('Valores distintos - Columna')
for column in train2.columns:
    print(train2[column].isnull().sum(), '/', train2[column].count(), '\t', column)
# Out:
# Valores distintos - Columna
# 0 / 16947 	 ID
# 0 / 16947 	 Region
# 0 / 16947 	 Territory
# 0 / 16947 	 Pricing, Delivery_Terms_Quote_Appr
# 0 / 16947 	 Pricing, Delivery_Terms_Approved
# 0 / 16947 	 Bureaucratic_Code_0_Approval
# 0 / 16947 	 Bureaucratic_Code_0_Approved
# 0 / 16947 	 Bureaucratic_Code
# 0 / 16947 	 Account_Created_Date
# 0 / 16947 	 Source
# 0 / 16947 	 Billing_Country
# 0 / 16947 	 Account_Name
# 0 / 16947 	 Opportunity_Name
# 0 / 16947 	 Opportunity_ID
# 0 / 16947 	 Sales_Contract_No
# 0 / 16947 	 Account_Owner
# 0 / 16947 	 Opportunity_Owner
# 0 / 16947 	 Account_Type
# 0 / 16947 	 Opportunity_Type
# 0 / 16947 	 Quote_Type
# 0 / 16947 	 Delivery_Terms
# 0 / 16947 	 Opportunity_Created_Date
# 0 / 16947 	 Quote_Expiry_Date
# 0 / 16947 	 Last_Modified_Date
# 0 / 16947 	 Last_Modified_By
# 0 / 16947 	 Product_Family
# 0 / 16947 	 Product_Name
# 0 / 16947 	 ASP_Currency
# 3209 / 13738 	 ASP
# 3209 / 13738 	 ASP_(converted)
# 0 / 16947 	 Planned_Delivery_Start_Date
# 75 / 16872 	 Planned_Delivery_End_Date
# 0 / 16947 	 Month
# 0 / 16947 	 Delivery_Quarter
# 0 / 16947 	 Delivery_Year
# 0 / 16947 	 TRF
# 0 / 16947 	 Total_Amount_Currency
# 59 / 16888 	 Total_Amount
# 0 / 16947 	 Total_Taxable_Amount_Currency
# 0 / 16947 	 Total_Taxable_Amount
# 0 / 16947 	 Stage

# %% [markdown]
# Los valores nan no generan una diferencia demasiado significativa para que las volumas ASP y AS
